# %% [markdown]
# ## Lecture 1 (04 Oct 2025)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kosavina/hse-python-2025/blob/main/Lecture_1.ipynb)

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Course Logistics
#
# * No required textbooks, but we will frequently use:
#   * [Python documentation](https://docs.python.org/)
#   * [Illustrative "Python Debugger"](https://pythontutor.com/python-debugger.html)
#   * [CheatSheet](https://www.pythoncheatsheet.org/)
#   * [RealPython articles](https://realpython.com/) (optional)
#
# * All course materials will be available on [GitHub](https://github.com/kosavina/hse-python-2025).
#
#
# * Course requirements:
#   * One problem set (Python Basics): up to 50 pts.
#   * Final exam (Python for Scientific Computing): up to 50 pts.
#   * Participation:
#     * 2 points for every attempt at solving a class problem regardless of correctness;
#     * Plus 1 point for a correct solution;
#     * Plus 1 point for an optimal or elegant solution.
#   * Collaborative work in small groups (max 4 people) is highly encouraged.
#
# * Course outline:
#   1.  Python Basics (3-4 weeks);
#   2.  Problem set;
#   3.  Python for Scientific Computing (3-4 weeks): NumPy, pandas, seaborn;
#   4.  Final exam.

# %% [markdown]
# ## Why programming?
#
# 1.  **Data Analysis and Modeling**
#   * Heavy reliance on data analytics in economics and finance
#   * Use programming for complex data sets
#   * Languages like Python or R tailored for statistical analysis
#   * Create predictive models and run simulations
#
# 2.  **Automation of Tasks**
#   * Automate routine tasks such as data collection and preprocessing
#   * Streamline workflow, save time and effort
#   * Execute repetitive calculations on multiple data sets quickly
#   * Focus on critical aspects of research or projects
#
# 3. **Custom Solutions**
#   * Off-the-shelf software may not meet specific needs
#   * Customize existing tools or build new ones
#   * Tailor solutions to specific research questions or business problems
#   * Greater adaptability in academic and corporate settings
#
# 4. **Competitive Advantage in the Job Market**
#   * Data manipulation and analysis skills are in high demand
#   * Attractive candidate for diverse roles like data analyst, financial modeler, etc.
#   * Multi-disciplinary skill set offers a significant edge
#   * Expand career prospects
#
# 5. **Enhanced Collaboration and Communication**
#   * Understand the language of engineers and data scientists
#   * Facilitate effective collaboration in team-oriented environments
#   * Bridging gaps between economic/financial theories and practical implementation
#   * Lead to more successful outcomes in both academic and business settings

# %% [markdown]
# ## Why Python?
#
# 1.  **User-Friendly Syntax**
#   * Python is easy to learn and read
#   * Intuitive syntax allows for quick uptake, even for beginners
#   * Spend less time troubleshooting syntax errors, more time on actual work
#
# 2.  **Extensive Libraries and Modules**
#   * Rich ecosystem of libraries tailored for data analysis (e.g., Pandas, NumPy)
#   * Statistical and modeling libraries (e.g., Statsmodels, scikit-learn)
#   * Libraries for finance (e.g., Quantlib, Zipline)
#
# 3.  **Strong Community Support**
#   * Large and active community, especially in data science and finance
#   * Easy access to tutorials, forums, and other resources
#   * Availability of pre-built solutions and code snippets
#
# 4.  **Versatility and Scalability**
#   * From small-scale data analysis to large machine learning projects
#   * Used in various industries, offering broader career opportunities
#   * Easily integrates with other languages and tools
#
# 5.  **Open Source and Cost-Effective**
#   * No need to purchase expensive software licenses
#   * Open-source nature allows for customization
#   * A cost-effective solution for students and professionals alike

# %% [markdown]
# ## What are the goals of this course?
#
# * To acquaint you with Python basics
# * Give you the opportunity to practice simple tasks before more advanced things in future courses
# * Teach you to independetly explore Python world

# %% [markdown]
# ## What are **NOT** the goals of this course?
#
# * Provide you with comprehensive presentation of Python features and capabilities (since it is not possible)
# * Discuss low-level details of Python workings and technical implementation (since it is not needed)
# * Teach you write production-grade code (since it is neither possible nor needed)

# %% [markdown]
# ## What is data?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## What is a computer?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Input units
#   * Keyboard
#   * Mouse
#   * Network Adapter
# * Output units
#   * Display
#   * Printer
#   * Network Adapter
# * Memory
#   * RAM
#   * CPU Cache
#   * EEPROM
# * CPU Ops
#   * Read
#   * Write
#   * Arithmetic ops
#   * Logical ops

# %% [markdown]
# ## Python program files
#
# * Python code is usually stored in text files with the file ending "`.py`":
#
#         myprogram.py
#
# * Every line in a Python program file is assumed to be a Python statement, or part thereof.
#
#     * The only exception is comment lines, which start with the character `#` (optionally preceded by an arbitrary number of white-space characters, i.e., tabs or spaces). Comment lines are usually ignored by the Python interpreter.
#
#
# * To run our Python program from the command line we use:
#
#         $ python myprogram.py
#
# * On UNIX systems it is common to define the path to the interpreter on the first line of the program (note that this is a comment line as far as the Python interpreter is concerned):
#
#         #!/usr/bin/env python
#
#   If we do, and if we additionally set the file script to be executable, we can run the program like this:
#
#         $ myprogram.py

# %% [markdown]
# # Useful Concepts

# %% [markdown]
# ## Classes and Objects

# %% [markdown]
# ### Formal Explanation

# %% [markdown]
# In Python, classes are blueprints for creating objects. A class defines a set of attributes and methods that its objects (instances) will have. Objects are instances of a class, representing concrete entities based on the class’s blueprint.
#
# A class is defined using the **class** keyword, followed by the class name and a colon:

# %%
class ClassName:
  def __init__(self, attribute):
    self.attribute = attribute

  def increment(self):
    self.attribute += 1

# %% [markdown]
# The **\_\_init\_\_** method is a special method (constructor) that initializes the object’s attributes. It is called when a new object is created.

# %% [markdown]
# An object is an instance of a class. Once a class is defined, you can create objects by calling the class:

# %%
obj = ClassName(10)

# %%
obj.attribute

# %%
obj.increment()

# %%
obj.attribute

# %% [markdown]
# Classes encapsulate both data (attributes) and behaviors (methods). This is key to the object-oriented paradigm in Python.

# %% [markdown]
# In Python, type() is a built-in function to get the type of an object (class name)

# %%
type(obj)

# %% [markdown]
# ### Intuitive Explanation

# %% [markdown]
# Car
#
# *   The initial mileage is zero (mileage)
# *   Maintenance every 10000 miles (dist_to_maintenance)
# *   The color is chosen by the buyer (color)
# *   It can move (move)

# %%
class PyCar:
  def __init__(self, color):
    self.mileage = 0
    self.dist_to_maintenance = 10000
    self.color = color

  def move(self, distance):
    self.mileage = self.mileage + distance
    self.dist_to_maintenance = self.dist_to_maintenance - distance

  def paint(self, new_color):
    self.color = new_color

# %%
my_car = PyCar('red')

# %%
print(my_car.color)

# %%
my_car.move(10)

# %%
my_car.mileage

# %%
my_car.dist_to_maintenance

# %% [markdown]
# Paint shop
# *   It can paint objects that have a color attribute

# %%
def paint(obj, new_color):
  obj.color = new_color
  return obj

# %%
my_car = paint(my_car, 'blue')

# %% [markdown]
# ## Memory (Variables and Namespaces)

# %% [markdown]
# Variable names in Python can contain alphanumerical characters `a-z`, `A-Z`, `0-9` and some special characters such as `_`. Normal variable names must start with a letter.
#
# By convention, variable names start with a lower-case letter, and Class names start with a capital letter.
#
# In addition, there are a number of Python keywords that cannot be used as variable names. These keywords are:
#
# 1.	True
# 2.	False
# 3.	None
# 4.	and
# 5.	as
# 6.	assert
# 7.	async
# 8.	await
# 9.	break
# 10.	class
# 11.	continue
# 12.	def
# 13.	del
# 14.	elif
# 15.	else
# 16.	except
# 17.	finally
# 18.	for
# 19.	from
# 20.	global
# 21.	if
# 22.	import
# 23.	in
# 24.	is
# 25.	lambda
# 26.	nonlocal
# 27.	not
# 28.	or
# 29.	pass
# 30.	raise
# 31.	return
# 32.	try
# 33.	while
# 34.	with
# 35.	yield
#
# Note: Be aware of the keyword `lambda`, which could easily be a natural variable name in a scientific program. But being a keyword, it cannot be used as a variable name.

# %% [markdown]
# [Built-in Functions](https://docs.python.org/3/library/functions.html)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Names resolution order:
#
# 1.  Local Namespace
# 2.  Enclosing Namespace
# 3.  Global Namespace
# 4.  Built-in Namespace

# %% [markdown]
# ## Mutability

# %% [markdown]
# Immutable types cannot be changed after their creation. Any operation that modifies an immutable object creates a new object in memory. Common examples include:
# * Integers
# * Floats
# * String
# * Tuples
# * Frozensets
# * Bytes
#
# Mutable types can be changed or modified after their creation. When a mutable object is altered, its original value is updated in memory. Common examples include:
# * Lists
# * Dictionaries
# * Sets
# * Bytearrays

# %% [markdown]
# Summary:
#
# 	•	Mutable types: Can be changed after creation (e.g., list, dict, set, bytearray).
# 	•	Immutable types: Cannot be changed after creation (e.g., int, float, str, tuple, frozenset, bytes).
#
# In general, immutable objects are hashable and can be used as keys in dictionaries or elements in sets, while mutable objects are not.

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Definition
#
# * Mathematical Function:
#
#   A mathematical function is a relation between a set of inputs (domain) and a set of possible outputs (codomain), such that each input is related to exactly one output. A mathematical function is typically written as  f(x) , where  x  is the input (argument) and  f(x)  is the output.
#
# * Python Function:
#
#   In Python, a function is a block of reusable code that performs a specific task. It takes arguments (inputs), processes them, and returns a result (output). In Python, functions are defined using the def keyword and can be invoked with specific arguments.

# %% [markdown]
# ### Inputs
#
# * Mathematical Function:
#
#   The input values (independent variable) come from a defined domain. For example, for the function  f(x) = x^2 , the input can be any real number, and the function returns its square.
#
# * Python Function:
#
#   Python functions can take multiple types of inputs, including integers, strings, lists, and other objects. For example, in Python, you can define a function like this:

# %%
def square(x):
    return x ** 2

# %%
def print_square(x):
    print(x ** 2)

# %%
x = square(10)

# %%
x

# %%
type(x)

# %%
x = print_square(10)

# %%
type(x)

# %% [markdown]
# ### Outputs
#
# * Mathematical Function:
#
#   A mathematical function produces one output for each input. The output depends on the function’s rule. For example, for the function  f(x) = x^2, when  x = 2, the output is  f(2) = 4
#
# * Python Function:
#
#   A Python function also returns a result based on its inputs. However, it can return multiple values (in the form of a tuple), and the output can be of any data type (int, float, string, list, etc.). It **never** returns nothing (at least None-type object is returned)

# %%
def multiply_and_return(a, b):
    return a * b

# %%
def multiply_and_print(a, b):
    print(a * b)

# %%
def multiply_print_and_return(a, b):
    print(a * b)
    return a * b

# %%
x = multiply_and_return(5, 6)
print(x)

# %%
x = multiply_and_print(5, 6)
print(x)

# %%
x = multiply_print_and_return(5, 6)
print(x)

# %% [markdown]
# # Assignment

# %% [markdown]
# The assignment operator in Python is `=`. Python is a dynamically typed language, so we do not need to specify the type of a variable when we create one.
#
# Assigning a value to a new variable creates the variable:

# %%
# variable assignments
x = 1.0
my_variable = 12.2

# %% [markdown]
# Although not explicitly specified, a variable does have a type associated with it. The type is derived from the value that was assigned to it.

# %%
type(x)

# %% [markdown]
# If we assign a new value to a variable, its type can change.

# %%
x = 1

# %%
type(x)

# %% [markdown]
# If we try to use a variable that has not yet been defined we get an `NameError`:

# %%
print(u)

# %% [markdown]
# # Fundamental types

# %%
# integers
x = 1
type(x)

# %%
# float
x = 1.
type(x)

# %%
# boolean
b1 = True
b2 = False

type(b1)

# %%
# complex numbers: note the use of `j` to specify the imaginary part
x = 1.0 - 4.0j
type(x)

# %%
print(x)

# %%
print(x.real, x.imag)

# %% [markdown]
# ### Type utility functions

# %% [markdown]
# The module `types` contains a number of type name definitions that can be used to test if variables are of certain types:

# %%
import types

# print all types defined in the `types` module
print(dir(types))

# %%
def multiply_and_return(a, b):
    return a * b

# %%
type(multiply_and_return) is types.FunctionType

# %%
type(multiply_and_return) is types.BuiltinFunctionType

# %%
x = 1.0

# check if the variable x is a float
type(x) is str

# %%
# check if the variable x is an int
type(x) is float

# %% [markdown]
# We can also use the `isinstance` method for testing types of variables:

# %%
isinstance(x, float)

# %% [markdown]
# ### Type casting

# %%
x = 1.5

print(x, type(x))

# %%
print(x, type(x))

x = int(x)

print(x, type(x))

# %%
x = 2.5
y = 3.5

# %%
print(int(x), int(y))

# %%
print(round(x), round(y))

# %%
import math

# %%
print(math.ceil(x), math.ceil(y))

# %%
float(int(x))

# %%
z = complex(x)

print(z, type(z))

# %% [markdown]
# Complex variables cannot be cast to floats or integers. We need to use `z.real` or `z.imag` to extract the part of the complex number we want:

# %%
y = bool(z.real)

print(z.real, " -> ", y, type(y))

y = bool(z.imag)

print(z.imag, " -> ", y, type(y))

# %% [markdown]
# # Operators and comparisons

# %% [markdown]
# Most operators and comparisons in Python work as one would expect:
#
# * Arithmetic operators `+`, `-`, `*`, `/`, `//` (integer division), '**' power

# %%
1 + 2, 1 - 2, 1 * 2, 1 / 2

# %%
1.0 + 2.0, 1.0 - 2.0, 1.0 * 2.0, 1.0 / 2.0

# %%
3 / 2

# %%
3 // 2

# %%
# Integer division of float numbers
3.0 // 2.0

# %%
# Note! The power operators in python isn't ^, but **
2 ** 2

# %% [markdown]
# Note: The `/` operator always performs a floating point division in Python 3.x.
# This is not true in Python 2.x, where the result of `/` is always an integer if the operands are integers.
# to be more specific, `1/2 = 0.5` (`float`) in Python 3.x, and `1/2 = 0` (`int`) in Python 2.x (but `1.0/2 = 0.5` in Python 2.x).

# %% [markdown]
# * The boolean operators are spelled out as the words `and`, `not`, `or`.

# %%
False and False

# %%
True and False

# %%
True or True

# %%
False or False

# %%
not False

# %% [markdown]
# * Comparison operators `>`, `<`, `>=` (greater or equal), `<=` (less or equal), `==` equality, `!=` non-equality, `is` identical.

# %%
x = 1
y = 2

# %%
x == y

# %%
x != y

# %%
2 > 1, 2 < 1

# %%
2 > 2, 2 < 2

# %%
2 >= 2, 2 <= 2

# %%
x = 1
y = 2

# %%
x = y

# %%
x == y

# %%
# equality
[1,2] == [1,2]
